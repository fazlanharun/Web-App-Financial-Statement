# %% [raw]
# ---
# title: Financial Statement Web App
# author : Mohammad Fazlan bin Harun
# description: Scraping the three financial statement from https://finance.yahoo.com/
# show-code: False
# params:
#     symbol:
#         input: text
#         label: What is the ticker?
#         value: CAP.PA
# ---

# %%
import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd

# %%
symbol = 'CAP.PA'

# %%
def get_page(url):
    # Set up the request headers that we're going to use, to simulate
    # a request by the Chrome browser. Simulating a request from a browser
    # is generally good practice when building a scraper
    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9',
        'Cache-Control': 'max-age=0',
        'Connection': 'close',
        'DNT': '1', # Do Not Track Request Header 
        'Pragma': 'no-cache',
        'Referrer': 'https://google.com',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
    }

    return requests.get(url, headers=headers)

def parse_rows(table_rows):
    parsed_rows = []

    for table_row in table_rows:
        parsed_row = []
        el = table_row.xpath("./div")

        none_count = 0

        for rs in el:
            try:
                (text,) = rs.xpath('.//span/text()[1]')
                parsed_row.append(text)
            except ValueError:
                parsed_row.append(np.NaN)
                none_count += 1

        if (none_count < 4):
            parsed_rows.append(parsed_row)
            
    return pd.DataFrame(parsed_rows)

def clean_data(df):
    df = df.set_index(0) # Set the index to the first column: 'Period Ending'.
    df = df.transpose() # Transpose the DataFrame, so that our header contains the account names
    
    # Rename the "Breakdown" column to "Date"
    cols = list(df.columns)
    cols[0] = 'Date'
    df = df.set_axis(cols, axis='columns', inplace=False)
    
    numeric_columns = list(df.columns)[1::] # Take all columns, except the first (which is the 'Date' column)

    for column_index in range(1, len(df.columns)): # Take all columns, except the first (which is the 'Date' column)
        df.iloc[:,column_index] = df.iloc[:,column_index].str.replace(',', '') # Remove the thousands separator
        df.iloc[:,column_index] = df.iloc[:,column_index].astype(np.float64) # Convert the column to float64
        
    return df

def scrape_table(url):
    # Fetch the page that we're going to parse
    page = get_page(url);

    # Parse the page with LXML, so that we can start doing some XPATH queries
    # to extract the data that we want
    tree = html.fromstring(page.content)

    # Fetch all div elements which have class 'D(tbr)'
    table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")
    
    # Ensure that some table rows are found; if none are found, then it's possible
    # that Yahoo Finance has changed their page layout, or have detected
    # that you're scraping the page.
    assert len(table_rows) > 0
    
    df = parse_rows(table_rows)
    df = clean_data(df)
        
    return df

# %%
df_income_statement = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/financials?p=' + symbol)
df_income_statement.set_index(['Date'],inplace=True)
income_statement = df_income_statement.T

print("\nScraping the Income Statement")

income_statement 

#numbers in thousands, 18160000.0 is read as 18,160,000,000 (18.16B)
# Out:
# Scraping the Income Statement
# Date                                                       ttm  12/31/2021  \
# Total Revenue                                       18160000.0  18160000.0
# Cost of Revenue                                     13368000.0  13368000.0
# Gross Profit                                         4792000.0   4792000.0
# Operating Expense                                    2732000.0   2732000.0
# Operating Income                                     2060000.0   2060000.0
# Net Non Operating Interest Income Expense            -157000.0   -157000.0
# Pretax Income                                        1680000.0   1680000.0
# Tax Provision                                         526000.0    526000.0
# Net Income Common Stockholders                       1157000.0   1157000.0
# Diluted NI Available to Com Stockholders             1157000.0   1157000.0
# Basic Average Shares                                       NaN         NaN
# Diluted Average Shares                                     NaN         NaN
# Total Operating Income as Reported                   1839000.0   1839000.0
# Rent Expense Supplemental                                  NaN         NaN
# Total Expenses                                      16100000.0  16100000.0
# Net Income from Continuing & Discontinued Opera...   1157000.0   1157000.0
# Normalized Income                                    1306766.0   1306766.0
# Interest Income                                        24000.0     24000.0
# Interest Expense                                      178000.0    178000.0
# Net Interest Income                                  -157000.0   -157000.0
# EBIT                                                 1858000.0   1858000.0
# Reconciled Cost of Revenue                          13368000.0  13368000.0
# Reconciled Depreciation                               672000.0    672000.0
# Net Income from Continuing Operation Net Minori...   1157000.0   1157000.0
# Total Unusual Items Excluding Goodwill               -218000.0   -218000.0
# Total Unusual Items                                  -218000.0   -218000.0
# Normalized EBITDA                                    2748000.0   2748000.0
# Tax Rate for Calcs                                         0.0         0.0
# Tax Effect of Unusual Items                           -68234.0    -68234.0
#
# Date                                                12/31/2020  12/31/2019  \
# Total Revenue                                       15848000.0  14125000.0
# Cost of Revenue                                     11712000.0  10274000.0
# Gross Profit                                         4136000.0   3851000.0
# Operating Expense                                    2378000.0   2286000.0
# Operating Income                                     1758000.0   1565000.0
# Net Non Operating Interest Income Expense            -144000.0    -62000.0
# Pretax Income                                        1355000.0   1354000.0
# Tax Provision                                         400000.0    502000.0
# Net Income Common Stockholders                        957000.0    856000.0
# Diluted NI Available to Com Stockholders              957000.0    856000.0
# Basic Average Shares                                  167620.0    166171.0
# Diluted Average Shares                                172556.0    171048.0
# Total Operating Income as Reported                   1502000.0   1433000.0
# Rent Expense Supplemental                             185000.0    176000.0
# Total Expenses                                      14090000.0  12560000.0
# Net Income from Continuing & Discontinued Opera...    957000.0    856000.0
# Normalized Income                                    1135365.0    930222.0
# Interest Income                                        48000.0     62000.0
# Interest Expense                                      178000.0    114000.0
# Net Interest Income                                  -144000.0    -62000.0
# EBIT                                                 1533000.0   1468000.0
# Reconciled Cost of Revenue                          11712000.0  10274000.0
# Reconciled Depreciation                               649000.0    545000.0
# Net Income from Continuing Operation Net Minori...    957000.0    856000.0
# Total Unusual Items Excluding Goodwill               -253000.0   -118000.0
# Total Unusual Items                                  -253000.0   -118000.0
# Normalized EBITDA                                    2435000.0   2131000.0
# Tax Rate for Calcs                                         0.0         0.0
# Tax Effect of Unusual Items                           -74635.0    -43778.0
#
# Date                                                12/31/2018
# Total Revenue                                       13197000.0
# Cost of Revenue                                      9627000.0
# Gross Profit                                         3570000.0
# Operating Expense                                    2159000.0
# Operating Income                                     1411000.0
# Net Non Operating Interest Income Expense             -48000.0
# Pretax Income                                        1171000.0
# Tax Provision                                         447000.0
# Net Income Common Stockholders                        730000.0
# Diluted NI Available to Com Stockholders              730000.0
# Basic Average Shares                                  167088.0
# Diluted Average Shares                                171697.0
# Total Operating Income as Reported                   1251000.0
# Rent Expense Supplemental                             366000.0
# Total Expenses                                      11786000.0
# Net Income from Continuing & Discontinued Opera...    730000.0
# Normalized Income                                     840622.0
# Interest Income                                        49000.0
# Interest Expense                                       88000.0
# Net Interest Income                                   -48000.0
# EBIT                                                 1259000.0
# Reconciled Cost of Revenue                           9627000.0
# Reconciled Depreciation                               302000.0
# Net Income from Continuing Operation Net Minori...    730000.0
# Total Unusual Items Excluding Goodwill               -179000.0
# Total Unusual Items                                  -179000.0
# Normalized EBITDA                                    1740000.0
# Tax Rate for Calcs                                         0.0
# Tax Effect of Unusual Items                           -68378.0

# %%
df_balance_sheet = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol)
df_balance_sheet.set_index(['Date'],inplace=True)
balance_sheet = df_balance_sheet.T

print("\nScraping the Balance Sheet")

balance_sheet

#numbers in thousands
# Out:
# Scraping the Balance Sheet
# Date                                       12/31/2021    12/31/2020  \
# Total Assets                             2.403300e+07  2.195400e+07
# Total Liabilities Net Minority Interest  1.555400e+07  1.583900e+07
# Total Equity Gross Minority Interest     8.479000e+06  6.115000e+06
# Total Capitalization                     1.512100e+07  1.323000e+07
# Common Stock Equity                      8.467000e+06  6.103000e+06
# Capital Lease Obligations                9.010000e+05  9.680000e+05
# Net Tangible Assets                     -3.169000e+06 -4.792000e+06
# Working Capital                          2.482000e+06  1.864000e+06
# Invested Capital                         1.520800e+07  1.418100e+07
# Tangible Book Value                     -3.169000e+06 -4.792000e+06
# Total Debt                               7.642000e+06  9.046000e+06
# Net Debt                                 3.612000e+06  5.242000e+06
# Share Issued                             1.723920e+05  1.687850e+05
# Ordinary Shares Number                   1.720050e+05  1.684480e+05
# Treasury Shares Number                   3.860450e+02  3.366560e+02
#
# Date                                      12/31/2019  12/31/2018
# Total Assets                             18135000.00  16498000.0
# Total Liabilities Net Minority Interest   9716000.00   9019000.0
# Total Equity Gross Minority Interest      8419000.00   7479000.0
# Total Capitalization                     10988000.00  10713000.0
# Common Stock Equity                       8424000.00   7480000.0
# Capital Lease Obligations                  813000.00     80000.0
# Net Tangible Assets                        117000.00   -648000.0
# Working Capital                           1443000.00   1924000.0
# Invested Capital                         11705000.00  10757000.0
# Tangible Book Value                        117000.00   -648000.0
# Total Debt                                4094000.00   3357000.0
# Net Debt                                   820000.00   1271000.0
# Share Issued                               169345.00    167294.0
# Ordinary Shares Number                     169099.00    167089.0
# Treasury Shares Number                        246.78       205.0

# %%
df_cash_flow = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/cash-flow?p=' + symbol)
df_cash_flow.set_index(['Date'],inplace=True)
cash_flow = df_cash_flow.T

print("\nScraping the Cash Flow")

cash_flow

#numbers in thousands
# Out:
# Scraping the Cash Flow
# Date                               ttm  12/31/2021  12/31/2020  12/31/2019  \
# Operating Cash Flow          2581000.0   2581000.0   1661000.0   1794000.0
# Investing Cash Flow          -678000.0   -678000.0  -1714000.0   -868000.0
# Financing Cash Flow         -1746000.0  -1746000.0    562000.0   -468000.0
# End Cash Position            3119000.0   3119000.0   2828000.0   2450000.0
# Capital Expenditure          -266000.0   -266000.0   -206000.0   -222000.0
# Issuance of Capital Stock     587000.0    587000.0    277000.0    253000.0
# Issuance of Debt              137000.0    137000.0   9308000.0    430000.0
# Repayment of Debt           -1498000.0  -1498000.0  -6273000.0   -448000.0
# Repurchase of Capital Stock  -197000.0   -197000.0   -514000.0         NaN
# Free Cash Flow               2315000.0   2315000.0   1455000.0   1572000.0
#
# Date                         12/31/2018
# Operating Cash Flow           1396000.0
# Investing Cash Flow           -728000.0
# Financing Cash Flow           -611000.0
# End Cash Position             2004000.0
# Capital Expenditure           -236000.0
# Issuance of Capital Stock      230000.0
# Issuance of Debt               525000.0
# Repayment of Debt             -592000.0
# Repurchase of Capital Stock   -483000.0
# Free Cash Flow                1160000.0
